# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvek/Whisper-model-Speach-to-text-/blob/main/Whisper_model_(Speach_to_text).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Speech to Text Transcription

# %% [markdown]
# INSTALL LIB

# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#      |████████████████████████████████| 4.9 MB 40.1 MB/s
#      |████████████████████████████████| 6.6 MB 57.9 MB/s
#      |████████████████████████████████| 120 kB 59.5 MB/s
# ...

# %% [markdown]
# LOAD THE LIB

# %%
import whisper 
model = whisper.load_model('medium')  #769M para/record
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:23<00:00, 64.2MiB/s]

# %%
# !wget -O audio.mp3
# Out:
# --2022-09-26 18:55:37--  ftp://c/%5CUsers%5Cbhuve%5CDownloads%5CHope(PaglaSongs)%20(2).mp3
#            => ‘audio.mp3’
# Resolving c (c)... failed: Name or service not known.
# wget: unable to resolve host address ‘c’

# %%
from IPython.display import Audio, display

display(Audio('//content//Hope(PaglaSongs) (2).mp3', autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
result = model.transcribe("//content//Hope(PaglaSongs) (2).mp3")
print(result["text"])
# Out:
# Detected language: English
# 100%|██████████| 11092/11092 [00:03<00:00, 3239.29frames/s]
#  Yeah. Rest in peace to all the kids that lost their lives in the parking shooter. This song is dedicated to you. Okay. Great. Okay. Okay.

# %%
import whisper
model = whisper.load_model('medium')
model.transcribe("audio.mp3")['text']
